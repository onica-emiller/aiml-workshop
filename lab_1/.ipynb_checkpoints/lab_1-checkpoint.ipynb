# %% [markdown]
# # Supplying Oil Well Sites
# This notebook demonstrates the processing of data collected by IoT sensors at multiple oil wells, for the purpose of prioritizing resupply of each well site.  Various chemicals are consumed at each well site at different rates and need to be replenished when running low.  In order to minimize resupply travel and costs, a prioritization algorithm is developed to yield the sites and routing of resupply trucks.

# %%
import pandas as pd
import numpy as np
import datetime
import boto3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sagemaker import get_execution_role
from  more_itertools import unique_everseen

# %matplotlib inline

# %% [markdown]
# ## Data Discovery
#
# Let's take a look at the data and get a handle on what we're looking at.

# %%
raw_data = pd.read_csv('onica3.csv')

# %% [markdown]
# Look at the first few rows of data

# %%
raw_data.head(20)
# Out:
#           site       asset           point  latestObservationTimestamp  \
# 0   2540109280  2540109284        LATITUDE                1.509070e+12
# 1   2540109280  2540109284     TANK_VOLUME                1.509070e+12
# 2   2540109280  2540109284   CHEMICAL_NAME                1.525990e+12
# 3   2540109280  2540109284  PRODUCT_VOLUME                         NaN
# 4   2540109280  2540109284  PRODUCT_VOLUME                         NaN
# 5   2540109280  2540109284  PRODUCT_VOLUME                         NaN
# 6   2540109280  2540109284  PRODUCT_VOLUME                         NaN
# 7   2540109280  2540109284  PRODUCT_VOLUME                         NaN
# 8   2540109280  2540109284  PRODUCT_VOLUME                         NaN
# 9   2540109280  2540109284  PRODUCT_VOLUME                         NaN
# 10  2540109280  2540109284  PRODUCT_VOLUME                         NaN
# 11  2540109280  2540109284  PRODUCT_VOLUME                         NaN
# 12  2540109280  2540109284  PRODUCT_VOLUME                         NaN
# 13  2540109280  2540109284  PRODUCT_VOLUME                         NaN
# 14  2540109280  2540109284  PRODUCT_VOLUME                         NaN
# 15  2540109280  2540109284  PRODUCT_VOLUME                         NaN
# 16  2540109280  2540109284  PRODUCT_VOLUME                         NaN
# 17  2540109280  2540109284  PRODUCT_VOLUME                         NaN
# 18  2540109280  2540109284  PRODUCT_VOLUME                         NaN
# 19  2540109280  2540109284  PRODUCT_VOLUME                         NaN
#
#    latestObservation  rollupStartTimestampMs  rollupEndTimestampMs  \
# 0          40.210997                     NaN                   NaN
# 1                330                     NaN                   NaN
# 2          MX 2-4621                     NaN                   NaN
# 3                NaN            1.529020e+12          1.529110e+12
# 4                NaN            1.529110e+12          1.529190e+12
# 5                NaN            1.529190e+12          1.529280e+12
# 6                NaN            1.529280e+12          1.529370e+12
# 7                NaN            1.529370e+12          1.529450e+12
# 8                NaN            1.529450e+12          1.529540e+12
# 9                NaN            1.529540e+12          1.529630e+12
# 10               NaN            1.529630e+12          1.529710e+12
# 11               NaN            1.529710e+12          1.529800e+12
# 12               NaN            1.529800e+12          1.529880e+12
# 13               NaN            1.529880e+12          1.529970e+12
# 14               NaN            1.529970e+12          1.530060e+12
# 15               NaN            1.530060e+12          1.530140e+12
# 16               NaN            1.530140e+12          1.530230e+12
# 17               NaN            1.530230e+12          1.530320e+12
# 18               NaN            1.530320e+12          1.530400e+12
# 19               NaN            1.530400e+12          1.530490e+12
#
#     numericSumValue  numericMinValue  numericMaxValue  numericLastValue
# 0               NaN              NaN              NaN               NaN
# 1               NaN              NaN              NaN               NaN
# 2               NaN              NaN              NaN               NaN
# 3       83789.68918       289.765304       292.905543        290.076368
# 4       83479.08299       288.751955       291.850937        289.273508
# 5       83168.02322       287.284156       291.472750        288.222951
# 6       82774.13694       286.285754       289.646092        286.382614
# 7       82427.02648       283.402635       289.124492        285.339462
# 8       82079.37321       283.387526       287.306508        284.377194
# 9       81577.48213       281.151281       285.764155        282.360036
# 10      81102.13754       280.494021       284.150552        280.569568
# 11      80769.22916       278.492171       283.334643        279.552162
# 12      80443.64008       277.590388       282.337372        277.590388
# 13      80040.02145       276.459154       280.463802        276.799300
# 14      79609.56762       274.971633       279.061718        275.968710
# 15      79280.82733       273.929753       277.535015        274.394592
# 16      78909.84654       272.447027       276.467064        273.368690
# 17      78502.74115       270.844134       274.931561        272.382911
# 18      78243.07228       270.251013       274.394592        270.515541
# 19      77918.52302       268.658108       273.432806        269.888529

# %% [markdown]
# Different rows appear to contain different information and populate different columns.  We're going to have to clean this up before we can do much with it.  Let's check how many different kinds of rows there are:

# %%
list(unique_everseen(raw_data['point']))
# Out:
# ['LATITUDE',
#  'TANK_VOLUME',
#  'CHEMICAL_NAME',
#  'PRODUCT_VOLUME',
#  'EST_DAYS_TO_EMPTY',
#  'AVERAGE_CHEMICAL_DAILY_USAGE',
#  'PERCENT_FULL',
#  'LONGITUDE']

# %% [markdown]
# How many sites and assets (chemical types):

# %%
len(list(unique_everseen(raw_data['site'])))
# Out:
# 250

# %%
len(list(unique_everseen(raw_data['asset'])))
# Out:
# 250

# %%
len(list(unique_everseen(zip(raw_data['site'],raw_data['asset']))))
# Out:
# 250

# %% [markdown]
# ## ETL (Extract, Transform and Load)
# The times are in the file as Unix epoch time (here, milliseconds from 1970-01-01); we'll turn them into datetime objects for clarity.

# %%
raw_data['rollupStartTimestampMs'] = pd.to_datetime(raw_data['rollupStartTimestampMs'], unit='ms')
raw_data['rollupEndTimestampMs'] = pd.to_datetime(raw_data['rollupEndTimestampMs'], unit='ms')
raw_data['latestObservationTimestamp'] = pd.to_datetime(raw_data['latestObservationTimestamp'], unit='ms')

# %%
raw_data.head(20)
# Out:
#           site       asset           point latestObservationTimestamp  \
# 0   2540109280  2540109284        LATITUDE        2017-10-27 02:06:40
# 1   2540109280  2540109284     TANK_VOLUME        2017-10-27 02:06:40
# 2   2540109280  2540109284   CHEMICAL_NAME        2018-05-10 22:06:40
# 3   2540109280  2540109284  PRODUCT_VOLUME                        NaT
# 4   2540109280  2540109284  PRODUCT_VOLUME                        NaT
# 5   2540109280  2540109284  PRODUCT_VOLUME                        NaT
# 6   2540109280  2540109284  PRODUCT_VOLUME                        NaT
# 7   2540109280  2540109284  PRODUCT_VOLUME                        NaT
# 8   2540109280  2540109284  PRODUCT_VOLUME                        NaT
# 9   2540109280  2540109284  PRODUCT_VOLUME                        NaT
# 10  2540109280  2540109284  PRODUCT_VOLUME                        NaT
# 11  2540109280  2540109284  PRODUCT_VOLUME                        NaT
# 12  2540109280  2540109284  PRODUCT_VOLUME                        NaT
# 13  2540109280  2540109284  PRODUCT_VOLUME                        NaT
# 14  2540109280  2540109284  PRODUCT_VOLUME                        NaT
# 15  2540109280  2540109284  PRODUCT_VOLUME                        NaT
# 16  2540109280  2540109284  PRODUCT_VOLUME                        NaT
# 17  2540109280  2540109284  PRODUCT_VOLUME                        NaT
# 18  2540109280  2540109284  PRODUCT_VOLUME                        NaT
# 19  2540109280  2540109284  PRODUCT_VOLUME                        NaT
#
#    latestObservation rollupStartTimestampMs rollupEndTimestampMs  \
# 0          40.210997                    NaT                  NaT
# 1                330                    NaT                  NaT
# 2          MX 2-4621                    NaT                  NaT
# 3                NaN    2018-06-14 23:46:40  2018-06-16 00:46:40
# 4                NaN    2018-06-16 00:46:40  2018-06-16 23:00:00
# 5                NaN    2018-06-16 23:00:00  2018-06-18 00:00:00
# 6                NaN    2018-06-18 00:00:00  2018-06-19 01:00:00
# 7                NaN    2018-06-19 01:00:00  2018-06-19 23:13:20
# 8                NaN    2018-06-19 23:13:20  2018-06-21 00:13:20
# 9                NaN    2018-06-21 00:13:20  2018-06-22 01:13:20
# 10               NaN    2018-06-22 01:13:20  2018-06-22 23:26:40
# 11               NaN    2018-06-22 23:26:40  2018-06-24 00:26:40
# 12               NaN    2018-06-24 00:26:40  2018-06-24 22:40:00
# 13               NaN    2018-06-24 22:40:00  2018-06-25 23:40:00
# 14               NaN    2018-06-25 23:40:00  2018-06-27 00:40:00
# 15               NaN    2018-06-27 00:40:00  2018-06-27 22:53:20
# 16               NaN    2018-06-27 22:53:20  2018-06-28 23:53:20
# 17               NaN    2018-06-28 23:53:20  2018-06-30 00:53:20
# 18               NaN    2018-06-30 00:53:20  2018-06-30 23:06:40
# 19               NaN    2018-06-30 23:06:40  2018-07-02 00:06:40
#
#     numericSumValue  numericMinValue  numericMaxValue  numericLastValue
# 0               NaN              NaN              NaN               NaN
# 1               NaN              NaN              NaN               NaN
# 2               NaN              NaN              NaN               NaN
# 3       83789.68918       289.765304       292.905543        290.076368
# 4       83479.08299       288.751955       291.850937        289.273508
# 5       83168.02322       287.284156       291.472750        288.222951
# 6       82774.13694       286.285754       289.646092        286.382614
# 7       82427.02648       283.402635       289.124492        285.339462
# 8       82079.37321       283.387526       287.306508        284.377194
# 9       81577.48213       281.151281       285.764155        282.360036
# 10      81102.13754       280.494021       284.150552        280.569568
# 11      80769.22916       278.492171       283.334643        279.552162
# 12      80443.64008       277.590388       282.337372        277.590388
# 13      80040.02145       276.459154       280.463802        276.799300
# 14      79609.56762       274.971633       279.061718        275.968710
# 15      79280.82733       273.929753       277.535015        274.394592
# 16      78909.84654       272.447027       276.467064        273.368690
# 17      78502.74115       270.844134       274.931561        272.382911
# 18      78243.07228       270.251013       274.394592        270.515541
# 19      77918.52302       268.658108       273.432806        269.888529

# %% [markdown]
# Some of the data rows are attributes of the site or asset, such as the latitude/longitude or chemical name.  We need to separate the timeseries data from these attribute data, and drop the columns not used in the timeseries data.

# %%
df_ts = raw_data[(raw_data.point == 'PRODUCT_VOLUME') | (raw_data.point == 'EST_DAYS_TO_EMPTY')| 
                 (raw_data.point == 'AVERAGE_CHEMICAL_DAILY_USAGE') | (raw_data.point == 'PERCENT_FULL')]

# drop attribute-related columns
del df_ts['latestObservationTimestamp']
del df_ts['latestObservation']

# %%
df_ts.head(20)
# Out:
#           site       asset           point rollupStartTimestampMs  \
# 3   2540109280  2540109284  PRODUCT_VOLUME    2018-06-14 23:46:40
# 4   2540109280  2540109284  PRODUCT_VOLUME    2018-06-16 00:46:40
# 5   2540109280  2540109284  PRODUCT_VOLUME    2018-06-16 23:00:00
# 6   2540109280  2540109284  PRODUCT_VOLUME    2018-06-18 00:00:00
# 7   2540109280  2540109284  PRODUCT_VOLUME    2018-06-19 01:00:00
# 8   2540109280  2540109284  PRODUCT_VOLUME    2018-06-19 23:13:20
# 9   2540109280  2540109284  PRODUCT_VOLUME    2018-06-21 00:13:20
# 10  2540109280  2540109284  PRODUCT_VOLUME    2018-06-22 01:13:20
# 11  2540109280  2540109284  PRODUCT_VOLUME    2018-06-22 23:26:40
# 12  2540109280  2540109284  PRODUCT_VOLUME    2018-06-24 00:26:40
# 13  2540109280  2540109284  PRODUCT_VOLUME    2018-06-24 22:40:00
# 14  2540109280  2540109284  PRODUCT_VOLUME    2018-06-25 23:40:00
# 15  2540109280  2540109284  PRODUCT_VOLUME    2018-06-27 00:40:00
# 16  2540109280  2540109284  PRODUCT_VOLUME    2018-06-27 22:53:20
# 17  2540109280  2540109284  PRODUCT_VOLUME    2018-06-28 23:53:20
# 18  2540109280  2540109284  PRODUCT_VOLUME    2018-06-30 00:53:20
# 19  2540109280  2540109284  PRODUCT_VOLUME    2018-06-30 23:06:40
# 20  2540109280  2540109284  PRODUCT_VOLUME    2018-07-02 00:06:40
# 21  2540109280  2540109284  PRODUCT_VOLUME    2018-07-03 01:06:40
# 22  2540109280  2540109284  PRODUCT_VOLUME    2018-07-03 23:20:00
#
#    rollupEndTimestampMs  numericSumValue  numericMinValue  numericMaxValue  \
# 3   2018-06-16 00:46:40      83789.68918       289.765304       292.905543
# 4   2018-06-16 23:00:00      83479.08299       288.751955       291.850937
# 5   2018-06-18 00:00:00      83168.02322       287.284156       291.472750
# 6   2018-06-19 01:00:00      82774.13694       286.285754       289.646092
# 7   2018-06-19 23:13:20      82427.02648       283.402635       289.124492
# 8   2018-06-21 00:13:20      82079.37321       283.387526       287.306508
# 9   2018-06-22 01:13:20      81577.48213       281.151281       285.764155
# 10  2018-06-22 23:26:40      81102.13754       280.494021       284.150552
# 11  2018-06-24 00:26:40      80769.22916       278.492171       283.334643
# 12  2018-06-24 22:40:00      80443.64008       277.590388       282.337372
# 13  2018-06-25 23:40:00      80040.02145       276.459154       280.463802
# 14  2018-06-27 00:40:00      79609.56762       274.971633       279.061718
# 15  2018-06-27 22:53:20      79280.82733       273.929753       277.535015
# 16  2018-06-28 23:53:20      78909.84654       272.447027       276.467064
# 17  2018-06-30 00:53:20      78502.74115       270.844134       274.931561
# 18  2018-06-30 23:06:40      78243.07228       270.251013       274.394592
# 19  2018-07-02 00:06:40      77918.52302       268.658108       273.432806
# 20  2018-07-03 01:06:40      77526.88315       267.875853       271.853957
# 21  2018-07-03 23:20:00      77194.13473       266.840944       270.403338
# 22  2018-07-05 00:20:00      76780.94956       265.211247       269.236650
#
#     numericLastValue
# 3         290.076368
# 4         289.273508
# 5         288.222951
# 6         286.382614
# 7         285.339462
# 8         284.377194
# 9         282.360036
# 10        280.569568
# 11        279.552162
# 12        277.590388
# 13        276.799300
# 14        275.968710
# 15        274.394592
# 16        273.368690
# 17        272.382911
# 18        270.515541
# 19        269.888529
# 20        268.592920
# 21        266.897984
# 22        265.773493

# %% [markdown]
# Now extract the static attribute data:

# %%
df_attributes = raw_data[(raw_data.point == 'LATITUDE') | (raw_data.point == 'LONGITUDE')| 
                         (raw_data.point == 'TANK_VOLUME') | (raw_data.point == 'CHEMICAL_NAME')]

#Drop timeseries-related columns
del df_attributes['rollupStartTimestampMs']
del df_attributes['rollupEndTimestampMs']
del df_attributes['numericSumValue']
del df_attributes['numericMinValue']
del df_attributes['numericMaxValue']
del df_attributes['numericLastValue']

# %%
df_attributes.head()
# Out:
#            site       asset          point latestObservationTimestamp  \
# 0    2540109280  2540109284       LATITUDE        2017-10-27 02:06:40
# 1    2540109280  2540109284    TANK_VOLUME        2017-10-27 02:06:40
# 2    2540109280  2540109284  CHEMICAL_NAME        2018-05-10 22:06:40
# 280  2540109280  2540109284      LONGITUDE        2017-10-27 02:06:40
# 370  2539597784  2539597788      LONGITUDE        2017-10-26 01:06:40
#
#     latestObservation
# 0           40.210997
# 1                 330
# 2           MX 2-4621
# 280       -110.394017
# 370       -110.103104

# %%
df_attributes.dtypes
# Out:
# site                                   int64
# asset                                  int64
# point                                 object
# latestObservationTimestamp    datetime64[ns]
# latestObservation                     object
# dtype: object

# %% [markdown]
# Perform some pandas pivot table magic to rearrange the data frame, and ensure the data are the right data type.

# %%
df_attributes = pd.pivot_table(df_attributes, 
                               index=['site','asset'], 
                               values=['latestObservation'],
                               columns=['point'], 
                               aggfunc=lambda x: ' '.join(map(str, x)))
# get rid of multi-level index
df_attributes = df_attributes.xs('latestObservation', axis=1, drop_level=True)
df_attributes = df_attributes.reset_index()

# convert the data with numeric data to the right data type
numeric_cols = ['LATITUDE','LONGITUDE','TANK_VOLUME']
df_attributes[numeric_cols] = df_attributes[numeric_cols].apply(pd.to_numeric)

# %%
df_attributes.head()
# Out:
# point        site       asset CHEMICAL_NAME   LATITUDE   LONGITUDE  \
# 0      2539575528  2539575532     MX 2-4621  40.386460 -110.103161
# 1      2539597784  2539597788     MX 6-1086  40.386459 -110.103104
# 2      2539744844  2539744848        B-8630  40.398602 -110.103326
# 3      2539767100  2539767104      MX 534-5  40.386557 -110.103326
# 4      2539789356  2539789360      MX 826-2  40.378977 -110.149287
#
# point  TANK_VOLUME
# 0              330
# 1              330
# 2              330
# 3              330
# 4              300

# %% [markdown]
# Merge timeseries data frame and attribute data frame.  Note that it's an inner join, so we're dropping sites with no timeseries information.

# %%
df = df_ts.merge(df_attributes, how = 'inner', on = ['site','asset'])

# %%
df.head(200)
# Out:
#            site       asset                         point  \
# 0    2540109280  2540109284                PRODUCT_VOLUME
# 1    2540109280  2540109284                PRODUCT_VOLUME
# 2    2540109280  2540109284                PRODUCT_VOLUME
# 3    2540109280  2540109284                PRODUCT_VOLUME
# 4    2540109280  2540109284                PRODUCT_VOLUME
# 5    2540109280  2540109284                PRODUCT_VOLUME
# 6    2540109280  2540109284                PRODUCT_VOLUME
# 7    2540109280  2540109284                PRODUCT_VOLUME
# 8    2540109280  2540109284                PRODUCT_VOLUME
# 9    2540109280  2540109284                PRODUCT_VOLUME
# 10   2540109280  2540109284                PRODUCT_VOLUME
# 11   2540109280  2540109284                PRODUCT_VOLUME
# 12   2540109280  2540109284                PRODUCT_VOLUME
# 13   2540109280  2540109284                PRODUCT_VOLUME
# 14   2540109280  2540109284                PRODUCT_VOLUME
# 15   2540109280  2540109284                PRODUCT_VOLUME
# 16   2540109280  2540109284                PRODUCT_VOLUME
# 17   2540109280  2540109284                PRODUCT_VOLUME
# 18   2540109280  2540109284                PRODUCT_VOLUME
# 19   2540109280  2540109284                PRODUCT_VOLUME
# 20   2540109280  2540109284                PRODUCT_VOLUME
# 21   2540109280  2540109284                PRODUCT_VOLUME
# 198        82.559705        83.777898         82.838997     MX 2-4621
# 199        82.073980        83.312594         82.540276     MX 2-4621
#
#       LATITUDE   LONGITUDE  TANK_VOLUME
# 0    40.210997 -110.394017          330
# 1    40.210997 -110.394017          330
# 2    40.210997 -110.394017          330
# 3    40.210997 -110.394017          330
# 4    40.210997 -110.394017          330
# 5    40.210997 -110.394017          330
# 6    40.210997 -110.394017          330
# 7    40.210997 -110.394017          330
# 8    40.210997 -110.394017          330
# 9    40.210997 -110.394017          330
# 10   40.210997 -110.394017          330
# 11   40.210997 -110.394017          330
# 12   40.210997 -110.394017          330
# 13   40.210997 -110.394017          330
# 14   40.210997 -110.394017          330
# 15   40.210997 -110.394017          330
# 16   40.210997 -110.394017          330
# 17   40.210997 -110.394017          330
# 18   40.210997 -110.394017          330
# 19   40.210997 -110.394017          330
# 20   40.210997 -110.394017          330
# 21   40.210997 -110.394017          330
# 22   40.210997 -110.394017          330
# 23   40.210997 -110.394017          330
# 24   40.210997 -110.394017          330
# 25   40.210997 -110.394017          330
# 26   40.210997 -110.394017          330
# 27   40.210997 -110.394017          330
# 28   40.210997 -110.394017          330
# 29   40.210997 -110.394017          330
# ..         ...         ...          ...
# 170  40.210997 -110.394017          330
# 171  40.210997 -110.394017          330
# 172  40.210997 -110.394017          330
# 173  40.210997 -110.394017          330
# 174  40.210997 -110.394017          330
# 175  40.210997 -110.394017          330
# 176  40.210997 -110.394017          330
# 177  40.210997 -110.394017          330
# 178  40.210997 -110.394017          330
# 179  40.210997 -110.394017          330
# 180  40.210997 -110.394017          330
# 181  40.210997 -110.394017          330
# 182  40.210997 -110.394017          330
# 183  40.210997 -110.394017          330
# 184  40.210997 -110.394017          330
# 185  40.210997 -110.394017          330
# 186  40.210997 -110.394017          330
# 187  40.210997 -110.394017          330
# 188  40.210997 -110.394017          330
# 189  40.210997 -110.394017          330
# 190  40.210997 -110.394017          330
# 191  40.210997 -110.394017          330
# 192  40.210997 -110.394017          330
# 193  40.210997 -110.394017          330
# 194  40.210997 -110.394017          330
# 195  40.210997 -110.394017          330
# 196  40.210997 -110.394017          330
# 197  40.210997 -110.394017          330
# 198  40.210997 -110.394017          330
# 199  40.210997 -110.394017          330
#
# [200 rows x 13 columns]

# %% [markdown]
# ## EDA (Exploratory Data Analysis)

# %% [markdown]
# The primary value appears to be the `PRODUCT_VOLUME`, and the others are derived from that.  Let's look at a few sites timeseries data.

# %%
def plot_sites(sites, df, ycol='numericLastValue'):
    for site in sites:
        df_site = df[df['site']==site]
        for cname, group in df_site.groupby('CHEMICAL_NAME'):
            ax = group.plot(x='rollupEndTimestampMs', y=ycol, title=str(site), marker='+', label=cname)
            ax.set_xlabel('Time')
            ax.set_ylabel('Volume')
            #print(site)

# %%
site_list = list(unique_everseen(df['site']))

# %%
num_sample = 5
variable = 'PERCENT_FULL' #'PRODUCT_VOLUME'

df_variable = df[df['point']==variable].copy()

plot_sites(np.random.choice(site_list, num_sample), df_variable)

# %% [markdown]
# Chemicals at most sites follow a logical pattern of steady depletion with occasional fill events rapidly increasing chemical volume levels.  Here are a few with a "typical" pattern:

# %%
normal_sites = [2539767100, 2543205088, 2546199776, 2615146580, 2550863632]
plot_sites(normal_sites, df_variable)

# %% [markdown]
# However, there are some timeseries which don't make sense, like the reported volume dropping to zero, or a single value in the timeseries.  These are likely sensor failures of some kind.  Other sites show slow increases in volume, which seems strange but could be from thermal expansion of the chemicals in the tank.

# %%
unusual_sites = [2612863532, 2552756476, 2545207496, 2616812000] #, 2552369860, 2553594584, 2539931224]
plot_sites(unusual_sites, df_variable)

# %% [markdown]
# # Empty Tank Prediction

# %% [markdown]
# Normalize time stamp as 'date' to capture all movement within one day and allow for grouping/sorting if needed

# %%
df_variable['date'] = df_variable['rollupEndTimestampMs'].dt.normalize()

# %%
df_variable.sort_values(['site','asset','rollupEndTimestampMs'], inplace=True)

# %% [markdown]
# FIXME: this doesn't account for time deltas

# %%
(df_variable['rollupEndTimestampMs'] - df_variable['rollupEndTimestampMs'].shift()).apply(lambda x: x.total_seconds())
# Out:
# 5276         NaN
# 5277     80000.0
# 5278     90000.0
# 5279     90000.0
# 5280     80000.0
# 5281     90000.0
# 5282     90000.0
# 5283     80000.0
# 5284     90000.0
# 5285     80000.0
# 5286     90000.0
# 5287     90000.0
# 5288     80000.0
# 5289     90000.0
# 5290     90000.0
# 5291     80000.0
# 5292     90000.0
# 5293     90000.0
# 5294     80000.0
# 5295     90000.0
# 5296     90000.0
# 5297     80000.0
# 5298     90000.0
# 5299     80000.0
# 5300     90000.0
# 5301     90000.0
# 5302     80000.0
# 5303     90000.0
# 5304     90000.0
# 5305     80000.0
#           ...
# 54576    80000.0
# 54577    90000.0
# 54578    90000.0
# 54579    80000.0
# 54580    90000.0
# 54581    90000.0
# 54582    80000.0
# 54583    90000.0
# 54584    90000.0
# 54585    80000.0
# 54586    90000.0
# 54587    80000.0
# 54588    90000.0
# 54589    90000.0
# 54590    80000.0
# 54591    90000.0
# 54592    90000.0
# 54593    80000.0
# 54594    90000.0
# 54595    90000.0
# 54596    80000.0
# 54597    90000.0
# 54598    80000.0
# 54599    90000.0
# 54600    90000.0
# 54601    80000.0
# 54602    90000.0
# 54603    90000.0
# 54604    80000.0
# 54605    90000.0
# Name: rollupEndTimestampMs, Length: 20009, dtype: float64

# %%
#Solve for daily percent full delta for any give site and asset

df_variable['percent_full_delta'] = np.where(df_variable['site'] == df_variable['site'].shift(), df_variable['numericLastValue'] - df_variable['numericLastValue'].shift() , np.nan)

# %%
def plot_multi(sites, df, ycol=['numericLastValue','percent_full_delta']):
    for site in sites:
        df_site = df[df['site']==site]
        for cname, group in df_site.groupby('CHEMICAL_NAME'):
            ax = group.plot(x='rollupEndTimestampMs', y=ycol, title=str(site), marker='+', label=[cname,'delta'])
            ax.set_xlabel('Time')
            ax.set_ylabel('Volume')

# %%
plot_multi([2546199776,2543205088,2553849160], df_variable) #, ycol='percent_full_delta')

# %%
threshold = 10
df_variable['fill_event'] = df_variable['percent_full_delta'] > threshold

# %%
df_mean_rate_of_depletion = df_variable[df_variable['fill_event']==False].groupby(['site','asset'], as_index=False).agg({"percent_full_delta":"mean"})
df_mean_rate_of_depletion.rename(columns={'percent_full_delta':'mean_rate_of_depletion'}, inplace=True)

# %%
df_mean_rate_of_depletion.head()
# Out:
#          site       asset  mean_rate_of_depletion
# 0  2539575528  2539575532               -1.528153
# 1  2539597784  2539597788               -2.461289
# 2  2539744844  2539744848               -0.806234
# 3  2539767100  2539767104               -0.303406
# 4  2539789356  2539789360               -0.829760

# %% [markdown]
# ***Apply a rate of depletion to the current chemical levels to predict time to empty.***

# %%
#Pull latest percent full levels by site and asset

df_fill_prediction = df_variable.groupby(['site','asset'], as_index=False).agg({"rollupEndTimestampMs":"max"})

# %%
#Ties with depletion rate count, great!

df_fill_prediction.shape
# Out:
# (248, 3)

# %%
#Merge lateset time stamp to be predicted on with rates of depletion

df_fill_prediction = pd.merge(df_fill_prediction, df_mean_rate_of_depletion, on=['site','asset'])

# %%
df_fill_prediction.head()
# Out:
#          site       asset rollupEndTimestampMs  mean_rate_of_depletion
# 0  2539575528  2539575532  2018-09-15 00:06:40               -1.528153
# 1  2539597784  2539597788  2018-09-11 23:53:20               -2.461289
# 2  2539744844  2539744848  2018-09-15 00:06:40               -0.806234
# 3  2539767100  2539767104  2018-09-15 00:06:40               -0.303406
# 4  2539789356  2539789360  2018-09-15 00:06:40               -0.829760

# %%
#Add other available fields at the latest timestamp for each site,asset

df_fill_prediction = pd.merge(df_fill_prediction, df_variable, on=['site','asset','rollupEndTimestampMs'])

# %%
#Data frame clean up

# df_fill_prediction.drop('point', axis=1, inplace=True)
# df_fill_prediction.drop('numericSumValue', axis=1, inplace=True) 
# df_fill_prediction.drop('numericMinValue', axis=1, inplace=True)
# df_fill_prediction.drop('numericMaxValue', axis=1, inplace=True)
# df_fill_prediction.drop('rollupStartTimestampMs', axis=1, inplace=True)
# df_fill_prediction.drop('fill_event', axis=1, inplace=True)
# df_fill_prediction.drop('percent_full_delta', axis=1, inplace=True)

# %%
df_fill_prediction.head()
# Out:
#          site       asset rollupEndTimestampMs  mean_rate_of_depletion  \
# 0  2539575528  2539575532  2018-09-15 00:06:40               -1.528153
# 1  2539597784  2539597788  2018-09-11 23:53:20               -2.461289
# 2  2539744844  2539744848  2018-09-15 00:06:40               -0.806234
# 3  2539767100  2539767104  2018-09-15 00:06:40               -0.303406
# 4  2539789356  2539789360  2018-09-15 00:06:40               -0.829760
#
#           point rollupStartTimestampMs  numericSumValue  numericMinValue  \
# 0  PERCENT_FULL    2018-09-13 23:06:40     14729.466330        50.284974
# 1  PERCENT_FULL    2018-09-10 22:53:20      6964.000305        80.778280
# 2  PERCENT_FULL    2018-09-13 23:06:40     19065.882760        65.123145
# 3  PERCENT_FULL    2018-09-13 23:06:40     22685.968420        76.032496
# 4  PERCENT_FULL    2018-09-13 23:06:40     21114.921680        72.533338
#
#    numericMaxValue  numericLastValue CHEMICAL_NAME   LATITUDE   LONGITUDE  \
# 27           130 2018-09-15           -0.792422       False     120.307239
# 28           130 2018-09-15            0.000000       False     594.094108
# 29           130 2018-09-15            0.000000       False           -inf
# ..           ...        ...                 ...         ...            ...
# 218          130 2018-09-15           30.123775        True      82.158799
# 219          225 2018-09-15           -0.934763       False      34.118490
# 220          330 2018-09-15           53.137078        True      52.212259
# 221          330 2018-09-15            0.319451       False     123.112508
# 222          330 2018-09-15           -0.820045       False      89.980453
# 223          300 2018-08-13           -0.725520       False      22.124274
# 224          340 2018-09-15           -1.833922       False      26.961827
# 225          255 2018-07-31           -2.540537       False      19.480833
# 226          230 2018-07-31           -1.277309       False      18.826964
# 227          340 2018-09-15           -1.855203       False      24.532470
# 228          340 2018-09-15           -1.458392       False      60.016608
# 229          230 2018-09-15           -1.310151       False       1.460315
# 230          130 2018-09-15            0.313732       False      50.813907
# 231          135 2018-09-15           -0.552379       False    1070.233207
# 232          130 2018-09-15            0.000000       False      17.333950
# 233          135 2018-09-15           -0.034452       False      33.683994
# 234          330 2018-08-11           -3.898386       False       8.563808
# 235          335 2018-08-11            0.009489       False     688.980323
# 236          230 2018-09-15           -1.030689       False     210.279746
# 237          135 2018-09-15           -1.314054       False      27.778680
# 238          135 2018-09-15           -2.912424       False      24.640899
# 239          135 2018-09-15           -0.088730       False     257.647869
# 240          135 2018-09-15           -0.107709       False      84.210805
# 241          225 2018-09-15           -0.833944       False     176.603303
# 242          135 2018-09-15           -0.099624       False      36.798929
# 243          135 2018-09-15           -0.070596       False       1.274831
# 244          135 2018-09-15            0.004818       False      43.769901
# 245          135 2018-09-15            0.371596       False      76.643357
# 246          135 2018-09-15           -0.416089       False      74.121426
# 247          335 2018-09-15           -3.629069       False       9.449618
#
# [248 rows x 18 columns]

# %% [markdown]
# ***Forecast the date at which the tank will reach empty.***

# %%
df_fill_prediction = df_fill_prediction.replace([np.inf, -np.inf], np.nan).dropna(subset=["days_to_empty"], how="any")

# %% [markdown]
# For this exercise, drop the pathological rows.  In production, these would be flagged for inspection.

# %%
bad_idx = df_fill_prediction[(df_fill_prediction['mean_rate_of_depletion']>=0) | (df_fill_prediction['mean_rate_of_depletion']<-10)].index
df_fill_prediction.drop(bad_idx, inplace=True)

# %%
df_fill_prediction.shape
# Out:
# (226, 18)

# %%
np.sort(df_fill_prediction['mean_rate_of_depletion'])
# Out:
# array([-8.39181055e+00, -7.52922413e+00, -5.99091128e+00, -5.48648210e+00,
#        -5.20494578e+00, -4.14584635e+00, -4.01882208e+00, -3.95814770e+00,
#        -3.94285692e+00, -3.73829049e+00, -3.56506729e+00, -3.55728470e+00,
#        -3.55257870e+00, -3.12569825e+00, -3.05042627e+00, -2.91449034e+00,
#        -2.89201050e+00, -2.82289330e+00, -2.77570894e+00, -2.74074262e+00,
#        -2.70023934e+00, -2.59091224e+00, -2.53836837e+00, -2.47566157e+00,
#        -2.46128855e+00, -2.41415981e+00, -2.36037864e+00, -2.35403015e+00,
#        -3.78075297e-01, -3.75331279e-01, -3.72033354e-01, -3.60221853e-01,
#        -3.53243769e-01, -3.52777133e-01, -3.49119909e-01, -3.44466529e-01,
#        -3.44090049e-01, -3.43091936e-01, -3.42469028e-01, -3.40859698e-01,
#        -3.31187033e-01, -3.24830496e-01, -3.22206130e-01, -3.17474439e-01,
#        -3.14830052e-01, -3.13919992e-01, -3.08272775e-01, -3.03405987e-01,
#        -2.97062930e-01, -2.91578465e-01, -2.79125890e-01, -2.77671501e-01,
#        -2.64616205e-01, -2.63793587e-01, -2.60380464e-01, -2.56510409e-01,
#        -2.37059208e-01, -2.36826660e-01, -2.34822670e-01, -2.28318867e-01,
#        -2.28289846e-01, -2.15956609e-01, -2.15620337e-01, -2.10451101e-01,
#        -2.05798833e-01, -2.03825484e-01, -1.99051684e-01, -1.98446770e-01,
#        -1.96729497e-01, -1.95377729e-01, -1.82466463e-01, -1.81071309e-01,
#        -1.74797481e-01, -1.56326965e-01, -1.54388325e-01, -1.26696162e-01,
#        -1.02720587e-01, -9.29214499e-02, -2.04852022e-02, -8.58896560e-03,
#        -4.05331092e-03, -2.75294275e-03, -2.63518793e-03, -1.82338604e-03,
#        -6.57912967e-04, -6.73706250e-05])

# %%
df_fill_prediction['mean_rate_of_depletion'].hist(bins=20)

# %%
a=df_fill_prediction.plot(x='mean_rate_of_depletion', y='days_to_empty', linewidth=0, marker='+')
a.set_ylim(0,100)
# Out:
# (0, 100)

# %% [markdown]
# ***Filter for working sensors and prioritize site and chemical fill requirements by time to empty.***

# %% [markdown]
# # Clustering (K-Means)

# %% [markdown]
# ***K-means on location and n = 5 clusters:***
# https://www.naftaliharris.com/blog/visualizing-k-means-clustering/

# %%
R = 6371.0 #-- mean radius of curvatureof Earth (km)

# %%
lat0 = np.median(df_fill_prediction['LATITUDE'])
lon0 = np.median(df_fill_prediction['LONGITUDE'])
print(lat0)
# Out:
# 40.230599999999995

# %%
df_fill_prediction['dN'] = np.radians(df_fill_prediction['LATITUDE'] - lat0) * R
df_fill_prediction['dE'] = np.radians(df_fill_prediction['LONGITUDE'] - lon0) * R * np.cos(np.radians(lat0))

# %%
from scipy import stats
from sklearn.cluster import KMeans

#Make a copy of DF
#must_fill = 30  #-- days
#df_tr = df_fill_prediction[df_fill_prediction['days_to_empty'] <= must_fill].copy()
df_tr = df_fill_prediction.copy()

#Standardize
#clmns = ['LONGITUDE', 'LATITUDE']
clmns = ['dE', 'dN']
df_tr_std = stats.zscore(df_tr[clmns])

# %%
#Cluster the data
n_clusters = 5
kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(df_tr_std)
labels = kmeans.labels_

#Glue back to original data
df_tr['cluster'] = labels

# %%
#Summarize clustering results

df_tr[['site','asset','cluster']].groupby(['cluster']).agg(['count'])
# Out:
#          site asset
#         count count
# cluster
# 0          70    70
# 1          16    16
# 2          20    20
# 3         115   115
# 4           5     5

# %%
#Visualize clustering results; scatter plot of LONGITUDE and LATITUDE
sns.lmplot('dE','dN',
           data=df_tr, 
           fit_reg=False, 
           hue="cluster",  
           scatter_kws={"marker": "D", 
                        "s": 100, "alpha": 0.3})
plt.title('Site Location Clusters')
plt.xlabel('Kilometers East')
plt.ylabel('Kilometers North')
# Out:
# Text(26.279322916666672, 0.5, 'Kilometers North')

# %% [markdown]
# ***Identify minimum days to empty to prioritize fill schedule by cluster:***

# %%
#Group data by clusters and indentify the minimum days to empty for each cluster

df_cluster_min = df_tr.groupby(['cluster'], as_index=False).agg({"days_to_empty":"min"})

# %%
#Rename the days_to_empty comlumn to prepare merge with df_fill_prediciton

df_cluster_min = df_cluster_min.rename(columns={'days_to_empty':'min_days_to_empty'})

# %%
#Review

df_cluster_min
# Out:
#    cluster  min_days_to_empty
# 0        0           0.000000
# 1        1           1.274831
# 2        2          17.614610
# 3        3           1.038947
# 4        4          31.508653

# %% [markdown]
# # Algorithm for "Traveling Salesman Problem" (TSP)

# %%
# Calculate the euclidian distance in n-space of the route r traversing cities (sites) c, ending at the path start.
path_distance = lambda r,c: np.sum([np.linalg.norm(c[r[p]]-c[r[p-1]]) for p in range(len(r))])

# Reverse the order of all elements from element i to element k in array r.
two_opt_swap = lambda r,i,k: np.concatenate((r[0:i],r[k:-len(r)+i-1:-1],r[k+1:len(r)]))

def two_opt(cities,improvement_threshold): # 2-opt Algorithm adapted from https://en.wikipedia.org/wiki/2-opt
    route = np.arange(cities.shape[0]) # Make an array of row numbers corresponding to cities (sites).
    improvement_factor = 1 # Initialize the improvement factor.
    best_distance = path_distance(route,cities) # Calculate the distance of the initial path.
    while improvement_factor > improvement_threshold: # If the route is still improving, keep going!
        distance_to_beat = best_distance # Record the distance at the beginning of the loop.
        for swap_first in range(1,len(route)-2): # From each city (site) except the first and last,
            for swap_last in range(swap_first+1,len(route)): # to each of the cities (sites) following,
                new_route = two_opt_swap(route,swap_first,swap_last) # try reversing the order of these cities (sites)
                new_distance = path_distance(new_route,cities) # and check the total distance with this modification.
                if new_distance < best_distance: # If the path distance is an improvement,
                    route = new_route # make this the accepted best route
                    best_distance = new_distance # and update the distance corresponding to this route.
        improvement_factor = 1 - best_distance/distance_to_beat # Calculate how much the route has improved.
    return route # When the route is no longer improving substantially, stop searching and return the route.

# Source: https://stackoverflow.com/questions/25585401/travelling-salesman-in-scipy

# %%
df_cluster_min.sort_values('min_days_to_empty', inplace=True)
df_cluster_min
# Out:
#    cluster  min_days_to_empty
# 0        0           0.000000
# 3        3           1.038947
# 1        1           1.274831
# 2        2          17.614610
# 4        4          31.508653

# %%
for c in df_cluster_min['cluster'].values:
    df_sites = df_tr[df_tr['cluster']==c]
    sites = df_sites[['dE','dN']].values
    
    # Find a good route with 2-opt ("route" gives the order in which to travel to each site by row number.)
    route = two_opt(sites,0.001)
    
    # Plot the recommended path
    ax = (df_sites.iloc[route]).plot(x='dE',y='dN', marker='D', title='Path for Cluster {}'.format(c))
    ax.set_xlabel('km East')
    ax.set_ylabel('km North')
    ax.get_legend().remove()
